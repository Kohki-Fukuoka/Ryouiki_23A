# %%
from google.colab import drive
drive.mount("/content/drive")
# %cd ./drive/University/4A/YOLO
# Out:
# Mounted at /content/drive
# [Errno 2] No such file or directory: './drive/University/4A/YOLO'
# /content

# %%
# YOLOの公式github
# !git clone https://github.com/ultralytics/ultralytics
# %cd ultralytics

# !pip install -r requirements.txt

from ultralytics import YOLO
model = YOLO("yolov8x.pt")

results = model("https://cs.kwansei.ac.jp/~kitamura/lecture/RyoikiJisshu/sample.mp4", save=True)
# Out:
# Cloning into 'ultralytics'...
# remote: Enumerating objects: 11637, done.
# remote: Counting objects: 100% (881/881), done.
# remote: Compressing objects: 100% (459/459), done.
# remote: Total 11637 (delta 556), reused 652 (delta 415), pack-reused 10756
# Receiving objects: 100% (11637/11637), 7.45 MiB | 24.37 MiB/s, done.
# Resolving deltas: 100% (7732/7732), done.
# /content/ultralytics/ultralytics/ultralytics
# ...
# 100%|██████████| 131M/131M [00:00<00:00, 140MB/s]
#
# ...
# 100%|██████████| 1.22M/1.22M [00:01<00:00, 1.15MB/s]
#
#     WARNING ⚠️ stream/video/webcam/dir predict source will accumulate results in RAM unless `stream=True` is passed,
#     causing potential out-of-memory errors for large sources or long-running streams/videos.
#
#     Usage:
#         results = model(source=..., stream=True)  # generator of Results objects
#         for r in results:
#             boxes = r.boxes  # Boxes object for bbox outputs
# ...

# %%
res_storage = [False for i in range(len(results[0].names))]

for result in results:
  boxes = result.boxes
  for box in boxes:
    res_storage[int(box.data[0][5])] = True

for i in range(len(res_storage)):
  if res_storage[i]:
    print(results[0].names[i])
# Out:
# person
# train
# traffic light
# bench
# backpack
# handbag
# suitcase
# frisbee
# sports ball
# baseball glove
# cup
# chair
